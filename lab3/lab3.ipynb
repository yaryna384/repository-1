# %%
a = input("Введіть число: ")
assert a.isdigit(), "Потрібно ввести число!"
print(f"введене число: {a}")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[6], line 2
#       1 a = input("Введіть число: ")
# ----> 2 assert a.isdigit(), "Потрібно ввести число!"
#       3 print(f"введене число: {a}")
#
# AssertionError: Потрібно ввести число!

# %%
class Figure:
    def __init__(self, type, length) -> None:
        assert length > 0, "Довжина має бути більшою за 0!"
        assert type in ["квадрат", "прямокутник", "трикутник"], "Дозволені фігури: квадрат, прямокутник, трикутник"
        self.type = type
        self.length = length

#a = Figure("трапеція", 12)
#b = Figure("квадрат", 0)
c = Figure("квадрат", 1)

# %%
class Name:
    def __init__(self, name, hobby) -> None:
        
        allowed_names = ["Богдан", "Анонім", "Ярина"] 
        if name not in allowed_names:
            raise ValueError(f"Дозволені імена: {', '.join(allowed_names)}")
        self.name = name
        
        if not hobby or hobby.strip() == "":
            raise ValueError("Хоббі не може бути порожнім")
        self.hobby = hobby

person1 = Name("Назар", "малювання")
print(person1.name, person1.hobby)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 13
#      10             raise ValueError("Хоббі не може бути порожнім")
#      11         self.hobby = hobby
# ---> 13 person1 = Name("Назар", "малювання")
#      14 print(person1.name, person1.hobby)
#
# Cell In[7], line 6, in Name.__init__(self, name, hobby)
#       4 allowed_names = ["Богдан", "Анонім", "Ярина"]
#       5 if name not in allowed_names:
# ----> 6     raise ValueError(f"Дозволені імена: {', '.join(allowed_names)}")
#       7 self.name = name
#       9 if not hobby or hobby.strip() == "":
#
# ValueError: Дозволені імена: Богдан, Анонім, Ярина
